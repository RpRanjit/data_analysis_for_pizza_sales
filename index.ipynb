# %%
import pandas as pd

# %%
df = pd.read_csv("pizza_sales.csv")

# %%
df.head(10)
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date   order_time  \
# 0         1         1     hawaiian_m         1   1/1/2015  11:38:36 AM
# 1         2         2  classic_dlx_m         1   1/1/2015  11:57:40 AM
# 2         3         2  five_cheese_l         1   1/1/2015  11:57:40 AM
# 3         4         2    ital_supr_l         1   1/1/2015  11:57:40 AM
# 4         5         2     mexicana_m         1   1/1/2015  11:57:40 AM
# 5         6         2     thai_ckn_l         1   1/1/2015  11:57:40 AM
# 6         7         3    ital_supr_m         1   1/1/2015  12:12:28 PM
# 7         8         3   prsc_argla_l         1   1/1/2015  12:12:28 PM
# 8         9         4    ital_supr_m         1   1/1/2015  12:16:31 PM
# 9        10         5    ital_supr_m         1   1/1/2015  12:21:30 PM
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
# 5       20.75        20.75          L        Chicken
# 6       16.50        16.50          M        Supreme
# 7       20.75        20.75          L        Supreme
# 8       16.50        16.50          M        Supreme
# 9       16.50        16.50          M        Supreme
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# 5  Chicken, Pineapple, Tomatoes, Red Peppers, Tha...
# 6  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 7  Prosciutto di San Daniele, Arugula, Mozzarella...
# 8  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 9  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
#
#                          pizza_name
# 0                The Hawaiian Pizza
# 1          The Classic Deluxe Pizza
# 2             The Five Cheese Pizza
# 3         The Italian Supreme Pizza
# 4                The Mexicana Pizza
# 5            The Thai Chicken Pizza
# 6         The Italian Supreme Pizza
# 7  The Prosciutto and Arugula Pizza
# 8         The Italian Supreme Pizza
# 9         The Italian Supreme Pizza

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#            pizza_id      order_id      quantity    unit_price   total_price
# count  48620.000000  48620.000000  48620.000000  48620.000000  48620.000000
# mean   24310.500000  10701.479761      1.019622     16.494132     16.821474
# std    14035.529381   6180.119770      0.143077      3.621789      4.437398
# min        1.000000      1.000000      1.000000      9.750000      9.750000
# 25%    12155.750000   5337.000000      1.000000     12.750000     12.750000
# 50%    24310.500000  10682.500000      1.000000     16.500000     16.500000
# 75%    36465.250000  16100.000000      1.000000     20.250000     20.500000
# max    48620.000000  21350.000000      4.000000     35.950000     83.000000

# %%
df.describe(include="all")
# Out:
#             pizza_id      order_id pizza_name_id      quantity  order_date  \
# count   48620.000000  48620.000000         48620  48620.000000       48620
# unique           NaN           NaN            91           NaN         358
# top              NaN           NaN    big_meat_s           NaN  11/26/2015
# freq             NaN           NaN          1811           NaN         261
# mean    24310.500000  10701.479761           NaN      1.019622         NaN
# std     14035.529381   6180.119770           NaN      0.143077         NaN
# min         1.000000      1.000000           NaN      1.000000         NaN
# 25%     12155.750000   5337.000000           NaN      1.000000         NaN
# 50%     24310.500000  10682.500000           NaN      1.000000         NaN
# 75%     36465.250000  16100.000000           NaN      1.000000         NaN
# max     48620.000000  21350.000000           NaN      4.000000         NaN
#
#          order_time    unit_price   total_price pizza_size pizza_category  \
# count         48620  48620.000000  48620.000000      48620          48620
# unique        16382           NaN           NaN          5              4
# top     12:32:00 PM           NaN           NaN          L        Classic
# freq             26           NaN           NaN      18526          14579
# mean            NaN     16.494132     16.821474        NaN            NaN
# std             NaN      3.621789      4.437398        NaN            NaN
# min             NaN      9.750000      9.750000        NaN            NaN
# 25%             NaN     12.750000     12.750000        NaN            NaN
# 50%             NaN     16.500000     16.500000        NaN            NaN
# 75%             NaN     20.250000     20.500000        NaN            NaN
# max             NaN     35.950000     83.000000        NaN            NaN
#
#                                         pizza_ingredients  \
# count                                               48620
# unique                                                 32
# top     Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# freq                                                 2416
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                       pizza_name
# count                      48620
# unique                        32
# top     The Classic Deluxe Pizza
# freq                        2416
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN

# %%
df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['pizza_id', 'order_id', 'pizza_name_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
import mysql.connector


connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Gaga@11327",
    database="pizza_sales"
)
print('Connection Successful')
# Out:
# Connection Successful

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL


connection_url = URL.create(
    "mysql+pymysql",
    username="root",
    password="Gaga@11327",
    host="localhost",
    port=3306,
    database="pizza_sales"
)

engine= create_engine(connection_url)

df.to_sql(
    "pizza_sales",
    con=engine,
    if_exists="replace",
    index=False
)
print("Data uploaded successfully!")
# Out:
# Data uploaded successfully!
